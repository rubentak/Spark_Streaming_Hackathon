# %% [markdown]
# # SparkStreaming Hackathon
#
# During this exercise, we will only provide some basic guidelines regarding how to proceed, but implementation details and business logic is up to you.
# * Get some streaming data from Reddit and send it using a socket.
#     * The data coming from Reddit should contain posts, or comments, or both
#     * It must be properly structured, containing at least the text and the creation date of the reddit post.
#     * You can pull data from several subreddits at once.
# * Get another process to receive the data from the socket and process it.
#     * Put the raw data on a temporary table in Spark (name: "raw"), so it can be queried, and save it on files to disk
#     * Get the references to other users (start with `/u/`), to other posts (start with `/r/`), and to external sites (url format), and the number of occurrences (suggested in 60 seconds windows every 5 seconds).
#     * Get top 10 important words in window using TF-IDF (Term Frequency, inverse Document Frequency). "Document" refers to the corpus of all previous posts/comments, as stored in table "raw".
#     * [Optional] Get the time range of the data (get it from the posts)
#     * [Optional] Get the sentiment analysis of every post and report the average one.
#     * [Optional] Add any other metric you may find interesting.
# * Output data
#     * Put the processed data on a temporary table on Spark (name: "metrics"), so the results can be queried.
#     * Save the results on files to disk.
#     * [Optional] Save the results to a DB.
# * Analyze the results (open question, you can decide what you want to display).
#     * Create a dashboard in jupyter-notebook to get the results (we should display the time range of the data, if available).
#     * [Optional] Create a web page (using some Python package) to visualize the results.
#     * [Optional] Visualize the results in real-time, automatically updated.
#     * [Optional] Display historical information (using data from local files or DB).
# * Deliverable
#     * All python code necessary to reproduce the results (producer side, consumer side, webapps), with instructions on how to run it and comments to explain the decisions behind part of the code.
#     * Output data files (cut to 1 MB if needed)
#     * docker setup if any
# Idea for content and analysis: there is currently a lot of complaints about reddit starting to monetize API, you can use the opportunity to try to characterise that (what are the main topics brought up ?). However, the topic choice is up to you. There are people discussing a very wide range of topics on reddit.

# %%
import praw
import credentials
import requests.auth
YOUR_CLIENT_ID = credentials.YOUR_CLIENT_ID
YOUR_CLIENT_SECRET = credentials.YOUR_CLIENT_SECRET
YOUR_USERNAME = credentials.YOUR_USERNAME
YOUR_PASSWORD = credentials.YOUR_PASSWORD
YOUR_USER_AGENT = credentials.YOUR_USER_AGENT

reddit = praw.Reddit(
    client_id='YOUR_CLIENT_ID',
    client_secret='YOUR_CLIENT_SECRET',
    username='YOUR_USERNAME',
    password='YOUR_PASSWORD',
    user_agent='YOUR_USER_AGENT'
)

# %%
subreddit = reddit.subreddit('api/travel/')
stream = subreddit.stream.submissions()

for post in stream:
    # Process the post as per your requirements
    print(post.title, post.created_utc)
# Out:
# ---------------------------------------------------------------------------
# ResponseException                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 subreddit = reddit.subreddit('api/travel/')
#       2 stream = subreddit.stream.submissions()
# ----> 4 for post in stream:
#       5     # Process the post as per your requirements
#       6     print(post.title, post.created_utc)
#
# File ~/miniconda3/lib/python3.10/site-packages/praw/models/util.py:138, in stream_generator(function, attribute_name, exclude_before, pause_after, skip_existing, **function_kwargs)
#     136 if not exclude_before:
#     137     function_kwargs["params"] = {"before": before_attribute}
# --> 138 for item in reversed(list(function(limit=limit, **function_kwargs))):
#     139     attribute = getattr(item, attribute_name)
#     140     if attribute in seen_attributes:
#
# ...

# %%
import socket

# Set up socket connection
host = 'localhost'  # Replace with the appropriate host
port = 1234  # Replace with the appropriate port
socket_conn = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
socket_conn.connect((host, port))

# Send data over the socket
data = "Hello, world!"  # Replace with the actual data to be sent
socket_conn.sendall(data.encode())

# Close the socket connection
socket_conn.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[3], line 7
#       5 port = 1234  # Replace with the appropriate port
#       6 socket_conn = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# ----> 7 socket_conn.connect((host, port))
#       9 # Send data over the socket
#      10 data = "Hello, world!"  # Replace with the actual data to be sent
#
# ConnectionRefusedError: [Errno 61] Connection refused
